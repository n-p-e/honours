# %%
from pathlib import Path
import pandas as pd

data_dir = Path("evaluation")

# %%
quasi = pd.read_json(data_dir / "quasi.json")
quasi_naive = pd.read_json(data_dir / "quasi-naive.json")

pd.merge(quasi[['dataset', 'solution_size', 'runtime_ms']], quasi_naive[['dataset', 'solution_size', 'runtime_ms']], on='dataset', suffixes=['', '_naive'])
# Out:
#                                        dataset  solution_size  runtime_ms  \
# 0     dataset/realworld/graph_ia-infect-dublin             16       0.226
# 1        dataset/realworld/graph_ia-enron-only              8       0.079
# 2        dataset/realworld/graph_scc_rt_lolgop             43       0.371
# 3         dataset/realworld/graph_scc_rt_qatif              3       0.003
# 4              dataset/realworld/graph_ca-GrQc             46       1.079
# ..                                         ...            ...         ...
# 134  dataset/realworld/graph_ca-hollywood-2009           2209    6945.818
# 135       dataset/realworld/graph_socfb-B-anon             29    6145.606
# 136       dataset/realworld/graph_inf-road-usa              4    2560.409
# 137      dataset/realworld/graph_socfb-uci-uni              6   12774.641
# 138          dataset/realworld/graph_soc-orkut             78   21750.930
#
#      solution_size_naive  runtime_ms_naive
# ...
